# %%
import streamlit as st
import matplotlib.pyplot as plt

# Título
st.title("🚚 Sistema de Roteirização de Entregas")

# Seleção de data
date_option = st.selectbox("Selecione o dia:", DATES)

# Simulação
res = simulate_day(date_option, DAILY)

# Resumo
st.subheader("Resumo Operacional")
daily_summary(res)

# Mapas por rota
st.subheader("Rotas por Veículo")
for i, r in enumerate(res["routes"]):
    assign = [v for k,v in res["assign"] if k == i][0]
    vname = assign.name if assign else "SEM_VEICULO"
    st.write(f"Rota {i} – Veículo: {vname}")
    plot_routes_by_vehicle(res, figsize=(6,6))
    st.pyplot()
# Out:
# 2025-11-20 14:25:39.283 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-20 14:25:39.533
# ...
#   command:
#
#     streamlit run C:\Users\User\anaconda3\lib\site-packages\ipykernel_launcher.py [ARGUMENTS]
# 2025-11-20 14:25:39.533 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-20 14:25:39.533 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-20 14:25:39.533 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-20 14:25:39.533 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-20 14:25:39.551 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# ...
